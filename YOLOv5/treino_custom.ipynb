# %% [markdown]
# ## 🧠 YOLOv5 - Treinamento com Dataset Personalizado
# ---
#
# ### 1. Introdução
#
# Este notebook demonstra como treinar um modelo YOLOv5 com um dataset personalizado utilizando a versão clonada do repositório oficial do Ultralytics. O exemplo aqui será com imagens anotadas com a classe `pessoa`, mas pode ser adaptado para outras categorias como `rosto`, `carro` etc.
#
# ---

# %% [markdown]
# ### 2. Importações e Verificar estrutura de pastas

# %%
import os
from pathlib import Path
from IPython.display import Image
from IPython.display import display
from PIL import Image as PILImage

# %%
os.listdir('.')
# Out:
# ['.ipynb_checkpoints',
#  'dataset',
#  'treino_custom.ipynb',
#  'treino_customizado.ipynb',
#  'yolov5']

# %% [markdown]
# ### 3. Clonar o repositório do YOLOv5 (se ainda não estiver clonado)

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %% [markdown]
# ### 4. Instalar dependências

# %%
# !pip install -r yolov5/requirements.txt

# %% [markdown]
# ### 5. Verificar estrutura do dataset

# %%
base = Path('datasets/imagens')
print("Conteúdo de datasets/imagens:")
for sub in base.glob("*/*"):
    print(sub)
# Out:
# Conteúdo de datasets/imagens:

# %% [markdown]
# Estrutura esperada:
# ```
# datasets/imagens/
# ├── train/
# │   ├── imagem1.jpg
# │   ├── imagem1.txt
# ├── val/
# │   ├── imagem2.jpg
# │   ├── imagem2.txt
# ```
#
# Os arquivos `.txt` devem estar no formato YOLO:
# ```
# <class_id> <x_center> <y_center> <width> <height>
# ```

# %% [markdown]
# ### 6. Criar o arquivo `data.yaml`

# %%
train: ../datasets/face_dataset/images/train
val: ../datasets/face_dataset/images/valid

nc: 1
names: ['rosto']
# Out:
#   Cell In[22], line 1
#     train: ../datasets/face_dataset/images/train
#            ^
# SyntaxError: invalid syntax

# %%
# Dentro da pasta Visao_Computacional/YOLOv5/
curl -L "<link_atual_do_roboflow>.zip" -o face.zip
unzip face.zip -d datasets/face_dataset

# %% [markdown]
# ### 7. Iniciar o treinamento com `train.py`

# %%
# !python yolov5/train.py \
    --img 640 \
    --batch 4 \
    --epochs 50 \
    --data yolov5/data.yaml \
    --weights yolov5s.pt \
    --name treino_customizado
# Out:
# Command 'git fetch origin' timed out after 5 seconds
# train: weights=yolov5s.pt, cfg=, data=yolov5/data.yaml, hyp=yolov5\data\hyps\hyp.scratch-low.yaml, epochs=50, batch_size=4, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=yolov5\data\hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5\runs\train, name=treino_customizado, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# git: 'Maques\Documents\Especialista_em_AI\EAI_06_Visao_Computacional\YOLOv5\yolov5' is not a git command. See 'git --help'.
# YOLOv5  2025-8-6 Python-3.13.5 torch-2.7.1+cu118 CPU
#
# ...

# %% [markdown]
# ### 8. Verificar resultados

# %%
Image(filename='yolov5/runs/train/treino_customizado/results.png', width=800)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 Image(filename='yolov5/runs/train/treino_customizado/results.png', width=800)
#
# File ~\anaconda3\envs\visao_cv\lib\site-packages\IPython\core\display.py:970, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#     968 self.unconfined = unconfined
#     969 self.alt = alt
# --> 970 super(Image, self).__init__(data=data, url=url, filename=filename,
#     971         metadata=metadata)
#     973 if self.width is None and self.metadata.get('width', {}):
#     974     self.width = metadata['width']
#
# File ~\anaconda3\envs\visao_cv\lib\site-packages\IPython\core\display.py:327, in DisplayObject.__init__(self, data, url, filename, metadata)
#     324 elif self.metadata is None:
#     325     self.metadata = {}
# --> 327 self.reload()
# ...

# %%
display(PILImage.open('yolov5/runs/train/treino_customizado/results.png'))

# %% [markdown]
# ---
#
# ## 9. Conclusão
#
# Este notebook demonstrou o processo de treinamento de um modelo YOLOv5 com dados anotados manualmente. Após o treinamento, os pesos ficarão salvos na pasta `yolov5/runs/train/treino_customizado/weights/best.pt`, e podem ser usados para inferência.
#
# Esse fluxo é fundamental para aplicações de Visão Computacional personalizadas, como detecção de pessoas, rostos, placas de veículos, produtos em prateleiras e muito mais.
#
# ---

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Jorge Maques\\Documents\\Especialista_em_AI\\EAI_06_Visao_Computacional\\YOLOv5'

# %%
# !type yolov5\data.yaml
# Out:
# train: ../datasets/face_dataset/images/train
# val: ../datasets/face_dataset/images/valid
#
# nc: 1
# names: ['rosto']
